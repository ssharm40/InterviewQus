# %%
# Decorator

def main_fun(fun):
    def inner_fun():
        print("Hi Bro")
        fun()
        print("Bye Sir")
    return inner_fun()

@main_fun
def call():
    print("I am Decorator")
# Out:
# Hi Bro
# I am Decorator
# Bye Sir

# %% [markdown]
# Mutable vs Immutable
#
#
# **When to prefer Tuple and when List**:
# If you limited data then go for tuple- like Weekdays bcoz it will be always 7
# otherwise we should go for list.

# %%
Which is better- Django or Flask?

Both are competitior, Normally django is used for very large application
whereas Flask is use for normal application
Flask is easy to learn
Flask is like a micro framework

# %%
Which library you use in python?---
Numpy
Pandas
OS
Json
date

# %%
## How to combine two df in pandas


import pandas as pd
df1= pd.DataFrame({'id':['A1', 'A2', 'A3', 'A4'], "name": ['shubham', 'Isru', 'Srinivas','Divya']})
df2= pd.DataFrame({'id':['B1', 'B2', 'B3', 'B4'], "name": ['Deepesh', 'Abhishek', 'Rajan', 'Prajjwal']})

# %%
final_df= pd.concat([df1,df2])
final_df
# Out:
#    id      name
# 0  A1   shubham
# 1  A2      Isru
# 2  A3  Srinivas
# 3  A4     Divya
# 0  B1   Deepesh
# 1  B2  Abhishek
# 2  B3     Rajan
# 3  B4  Prajjwal

# %%
# Second Way- Append Method

final_df= df1.append(df2)
final_df
# Out:
#    id      name
# 0  A1   shubham
# 1  A2      Isru
# 2  A3  Srinivas
# 3  A4     Divya
# 0  B1   Deepesh
# 1  B2  Abhishek
# 2  B3     Rajan
# 3  B4  Prajjwal

# %%
# Read File in python
with open('abc.txt') as f:
    lines=f.readlines()
for i in lines:
    print(i)


# Why we use with keyword here?------ Bcoz if you are using with then we don't need to close the file. once we out from the
#                                     indentation, it willbe closed.
# Out:
# hello xyz bhai
#
# aap kaise ho
#
# kya kr rhe ho

# %%
# Check Palindrome

s="niti"

if s==s[::-1]:
    print("Palindrome")
else:
    print("No")
# Out:
# No

# %%
# Now apply it by another method

s=input("Enter the string: ")
temp=s
rev=""
while len(s)!=0:
    lst=s[-1]
    s=s[:-1]
    rev=rev+lst
if temp==rev:
    print("It's palindrome")
else:
    print("Not Palinrome")
# Out:
# Enter the string: Nitin
# Not Palinrome

# %% [markdown]
# ## Git Common Commands:
#
#
# Basic commands I know that I used for my project works
#
#
# 1) **git init repository_name** : this command is used to create a new repository
#
# 2) **git pull**: When you want to copt the data of repository in your local
#
# 3) **git clone url** : this is used to copy a repository from an existing URL
#
# 4) **git checkout** :  To create seprate branch then we use checkout
#
# 5) **git add.** : This will reflect all the changes
#
# 6) **git status** : This command list all the files that needs to be commited
#
# 7) **git commit -m [msg]** : Save the new data with a msg
#
# 8) **git push**- All changes will be push to production

# %% [markdown]
# ## Basic of Git- 10 Basic Commands
#
#
# 1)  git init:    **git init rep_name** is used to initialise a new repository. It create a .git folder in the current working                    directory.
#
#
# 2)  git add:     **git add.** this wil reflect all the changes
#
#
# 3)  git commit:  **git commit -m msg**this command is used to save the changes to the local repository. This command help you                    to keep all the records of all the changes made.
#
#
# 4)  git status : **Which **
#
#
#
# 5)  git merge  :  git merge command is used to integrate diff branches into single brnaches.
#
# 6)  git push   :  it use to upload the contect from local repository to remote repository.
#
# 7)  git pull   :  its used to fetch the data from remote repo tolocal machine.
#
# 8)  git clone  :  git clone url            Copy the data from remote
#
#
# 9)  git branch:   this command is used to create, delete,list all branch, rename the branches
#                   git branch bl_ac => this will create new branch
#
#
#
# 10) git check-out :

# %%
What library we use for setting up with pgadmin

psycopyg2

# %% [markdown]
# What is Agile Methodologies?
# Agile is a set of methods that follows iterative development.
# It support continuous change bcoz changes in requirement.
#
#
#
# Here we divide our large project into small chunks then we release the project after thata we will get some feedback from our
# customer then we will enhance features accordingly and then re release the projec.
#
#
#
# Large Project ---> Small Chunks ---> Release ---> Feedback ---> Enhance ---> Re Release
#
#
#
# **manifesto**
#
# Customer Collaboration
# Responding to change
#
#
#
# **Principle**
# Customer Statisfaction- bcoz feedback is very important
#
# Welcome change-
#
# Early delivery of Product
#
# Deliver Product Frequentl
#
#
# **Benefit of Agile**
# Transparency
# Predictable cost
# Allows for change
#
#
#
# **Spirint**
# ====> Sprint means small iteration to be developed and give it to the client,
# Then follow the second sprint
#
#
#
#
#
# **Practise of Agile**
#
# Daily Standup
# Sprints
# Splitting user stories
# Pair programming
# Test-driven development
#
#
#
#
#
# **Diff between Waterfall & Agile methodilogy:**
# **Agile Model** is a continuous iteration life cycle model for developing and testing a software
# The entire process is divided into multiple sprints
# Changes can be made after the initial planning
#
#
# Where as **Waterfall** is linear model where we developed complete model in one go.
# The entire process is breaken down into multiple phase
# Make any changes is typical.
#
#
#
# **Diff Types of Agile Methodologies**:
#
# Extreme Methodologies
# Kanban
# Scrum
# Crystal
